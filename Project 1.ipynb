# %%
import pandas as pd
from pandas import read_excel

# %%
df=pd.read_excel('C:/Users/khair/Desktop/MScBIA/Sem 3/Project 1/Dataset/MNT Data/test.xlsx')

# %%
df.head()
# Out:
#    ID TAG Request                       Machines Name  Issue By   Location  \
# 0             207                              Others  jamallul  SVR - SV1
# 1             208  Schmetz Vacuum Heat Treatment No 1     Eammy  SVR - SV3
# 2             211           Wet blasting machine No 1  jamallul  SVR - SV1
# 3             212  Schmetz Vacuum Heat Treatment No 1  jamallul  SVR - SV3
# 4             213                              Others     Amiru  LPT - CL3
#
#   Division                             Description Of problem  \
# 0      NaN                  Water leaking at cleaning ceiling
# 1      NaN  Rapid cooling temperature meter broken, not fu...
# 2      NaN                                  Water no pressure
# 3      NaN                           Furnaces chamber damaged
# 4      NaN                        Vacuum cleaner Motor faulty
#
#      Date & Time Issue Status Of machine   Date & Time Attand Attand By  \
# ...

# %%
df.shape
# Out:
# (9775, 48)

# %%
df.isnull().sum()
# Out:
# ID TAG Request                          0
# Machines Name                           4
# Issue By                                6
# Location                                4
# Division                             3585
# Description Of problem                 34
# Date & Time Issue                       4
# Status Of machine                      15
# Date & Time Attand                     17
# Attand By                              13
# Detail of Problem                      32
# Corrective action                      85
# Remark by technician                 7071
# Date & Time start repair             2176
# Date & Time Finish                    100
# Possible Root Cause                   500
# Total breakdown time                 7270
# Completed By                         2714
# Current Status                       5666
# Priority                             3938
# Item Code                            6811
# Item Detail                          9525
# ...

# %%
df.isnull().mean() * 100
# Out:
# ID TAG Request                         0.000000
# Machines Name                          0.040921
# Issue By                               0.061381
# Location                               0.040921
# Division                              36.675192
# Description Of problem                 0.347826
# Date & Time Issue                      0.040921
# Status Of machine                      0.153453
# Date & Time Attand                     0.173913
# Attand By                              0.132992
# Detail of Problem                      0.327366
# Corrective action                      0.869565
# Remark by technician                  72.337596
# Date & Time start repair              22.260870
# Date & Time Finish                     1.023018
# Possible Root Cause                    5.115090
# Total breakdown time                  74.373402
# Completed By                          27.764706
# Current Status                        57.964194
# Priority                              40.286445
# ...
